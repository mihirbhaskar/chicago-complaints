# %% [markdown]
# # Cleaning various Chicago Open Data Portal datasets
# #### Abhilash Biswas
# #### 11/23/2021
#
# This file merges Census tract id from ACS dataset to the geo-coordinates of 5 datasets obtained from the Chicago open data portal. Additionally, this file also attaches census tract ID to the 84 civilian killings that has happened in Chicago till date.
#
# The 5 datasets extracted from Chicago open data portal are:
# 1. Police station locations
# 2. Fire station locations
# 3. List of public schools (as of 2019) (2016-17 data also available)
# 4. List of Parks maintained by Chicago Park district
# 5. List of all licensed commercial establishments
#
# In addition to these 5, the police killings dataset is obtained from the MPV csv file.
#
# ### Process
# 1. Get the clean ACS dataset (containing boundary polygons and census ids (geo id)) and convert it into a geopandas dataframe
# 2. Obtain each of the above 6 predictor datasets and convert it into geopandas dataframe
# 3. Merge the geo ids to each of the predictor datasets
# 4. Aggregate the information for each predictor at a census tract level
# 5. Combine all the datasets into 1

# %%
#Import all packages
import pandas as pd
import censusdata
from tabulate import tabulate
import matplotlib.pyplot as plt
from sodapy import Socrata
import geopandas as gpd
from shapely import wkt
import json
import requests
from pyprojroot import here

# %% [markdown]
# # Census tract information

# %%
#Get the cleaned csv
acs = pd.read_csv(here('./data/CleanACSFile.csv'))

#Convert it into a geopandas dataframe
acs['geometry'] = acs['geometry'].apply(wkt.loads)
gdf_acs = gpd.GeoDataFrame(acs, crs = 'epsg:4326')

gdf_acs
# Out:
#                    geo_id  B01001_001E  DP02_0002PE  DP02_0004PE  DP02_0006PE  \
# 0    1400000US17031010100       4599.0         23.8          2.5         39.5
# 1    1400000US17031010201       7455.0         33.7          7.2         28.3
# 2    1400000US17031010202       2896.0         23.1         13.6         23.0
# 3    1400000US17031010300       6485.0         25.3          7.4         25.2
# 4    1400000US17031010400       5213.0         17.4          5.7         36.4
# ..                    ...          ...          ...          ...          ...
# 793  1400000US17031843500      10169.0         33.0         22.8         25.6
# 794  1400000US17031843600       2898.0         12.5          8.8         18.9
# 795  1400000US17031843700       2527.0         51.3          5.6         17.9
# 796  1400000US17031843800       1520.0         19.8          9.5         31.9
# 797  1400000US17031843900       3430.0         10.7          8.7         22.5
#
#      DP02_0010PE  DP02_0014PE  DP02_0015PE  DP02_0016E  DP02_0017E  ...  \
# 0           34.2         21.5          8.7        1.89        3.05  ...
# 1           30.8         28.2         14.9        2.65        3.50  ...
# 2           40.4         26.9         17.9        2.27        3.31  ...
# 3           42.1         17.0         18.7        1.80        2.79  ...
# 4           40.5         12.5         10.7        1.82        2.93  ...
# ..           ...          ...          ...         ...         ...  ...
# 793         18.6         50.9         10.2        3.58        4.03  ...
# 794         59.7         28.4         20.9        2.06        2.90  ...
# 795         25.1         39.6         22.4        2.55        3.50  ...
# 796         38.8         32.4         32.5        2.23        3.04  ...
# 797         58.0         13.1         34.6        1.76        2.97  ...
#
#      DP05_0018E  DP05_0019PE  DP05_0024PE  DP05_0037PE  DP05_0038PE  \
# 0          35.6         19.9          6.0         46.7         45.2
# 1          34.8         25.6          6.8         46.4         33.8
# 2          35.0         20.3         13.1         46.7         33.9
# 3          42.2         14.5         18.5         59.6         30.9
# 4          25.2         10.7          5.0         70.8         21.3
# ..          ...          ...          ...          ...          ...
# 793        29.9          3.7          2.2         31.0         63.4
# 794        33.6         26.9         11.7          7.6         87.6
# 795        35.8         27.9          9.8         80.0          4.0
# 796        39.9         22.4         17.4         25.8         66.4
# 797        46.1         13.5         21.9          5.3         90.1
#
#      DP05_0044PE  DP05_0058PE  DP05_0071PE  \
# 0            1.0          3.4         11.4
# 1            4.0          8.0         22.4
# 2            5.4          1.4         26.0
# 3            1.0          4.2         16.9
# 4            4.6          1.8          7.5
# ..           ...          ...          ...
# 793          0.3          0.0         26.3
# 794          0.9          2.4          7.9
# 795          6.7          6.4         25.7
# 796          7.3          0.5          7.0
# 797          1.7          1.8          1.1
#
#                                               geometry      GEOID10
# 0    MULTIPOLYGON (((-87.67720 42.02294, -87.67007 ...  17031010100
# 1    MULTIPOLYGON (((-87.68465 42.01949, -87.68045 ...  17031010201
# 2    MULTIPOLYGON (((-87.67685 42.01941, -87.67339 ...  17031010202
# 3    MULTIPOLYGON (((-87.67133 42.01937, -87.66950 ...  17031010300
# 4    MULTIPOLYGON (((-87.66345 42.01283, -87.66133 ...  17031010400
# ..                                                 ...          ...
# 793  MULTIPOLYGON (((-87.70504 41.84452, -87.70258 ...  17031843500
# 794  MULTIPOLYGON (((-87.61150 41.81128, -87.60661 ...  17031843600
# 795  MULTIPOLYGON (((-87.69676 41.95046, -87.69445 ...  17031843700
# 796  MULTIPOLYGON (((-87.64554 41.80886, -87.64068 ...  17031843800
# 797  MULTIPOLYGON (((-87.59295 41.77508, -87.59170 ...  17031843900
#
# [798 rows x 96 columns]

# %% [markdown]
# # Chicago police district station locations

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("z8bn-74gv", limit=2000)

# Convert to pandas DataFrame
police_stations = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
police_stations['lat'] = ''
police_stations['long'] = ''


for i in range(0,len(police_stations)):
    police_stations['lat'].iloc[i] = police_stations['location'].iloc[i]['latitude']
    police_stations['long'].iloc[i] = police_stations['location'].iloc[i]['longitude']
    

    
police_stations = police_stations[['district','district_name','zip','location','lat','long']]
police_stations
# Out:
#         district   district_name    zip  \
# 0   Headquarters    Headquarters  60653
# 1             18      Near North  60610
# 2             19       Town Hall  60613
# 3             20         Lincoln  60625
# 4             22     Morgan Park  60643
# 5             24     Rogers Park  60626
# 6             25   Grand Central  60639
# 7              1         Central  60616
# 8              2       Wentworth  60609
# 9              3  Grand Crossing  60637
# 10             4   South Chicago  60617
# 11             5         Calumet  60628
# 12             6         Gresham  60620
# 13             7       Englewood  60636
# 14             8    Chicago Lawn  60629
# 15             9         Deering  60608
# 16            10           Ogden  60623
# 17            11        Harrison  60612
# 18            12       Near West  60608
# 19            14     Shakespeare  60647
# 20            15          Austin  60644
# 21            16  Jefferson Park  60630
# 22            17     Albany Park  60630
#
#                                              location            lat  \
# 0   {'latitude': '41.8307016873', 'longitude': '-8...  41.8307016873
# 1   {'latitude': '41.9032416531', 'longitude': '-8...  41.9032416531
# 2   {'latitude': '41.9474004564', 'longitude': '-8...  41.9474004564
# 3   {'latitude': '41.9795495131', 'longitude': '-8...  41.9795495131
# 4   {'latitude': '41.6914347795', 'longitude': '-8...  41.6914347795
# 5   {'latitude': '41.9997634842', 'longitude': '-8...  41.9997634842
# 6   {'latitude': '41.9186088912', 'longitude': '-8...  41.9186088912
# 7   {'latitude': '41.8583725929', 'longitude': '-8...  41.8583725929
# 8   {'latitude': '41.8018110912', 'longitude': '-8...  41.8018110912
# 9   {'latitude': '41.7664308925', 'longitude': '-8...  41.7664308925
# 10  {'latitude': '41.7079332906', 'longitude': '-8...  41.7079332906
# 11  {'latitude': '41.6927233639', 'longitude': '-8...  41.6927233639
# 12  {'latitude': '41.7521368378', 'longitude': '-8...  41.7521368378
# 13  {'latitude': '41.7796315359', 'longitude': '-8...  41.7796315359
# 14  {'latitude': '41.778987189', 'longitude': '-87...   41.778987189
# 15  {'latitude': '41.8373944311', 'longitude': '-8...  41.8373944311
# 16  {'latitude': '41.8566845327', 'longitude': '-8...  41.8566845327
# 17  {'latitude': '41.8735822883', 'longitude': '-8...  41.8735822883
# 18  {'latitude': '41.8629766244', 'longitude': '-8...  41.8629766244
# 19  {'latitude': '41.9211033246', 'longitude': '-8...  41.9211033246
# 20  {'latitude': '41.8800834614', 'longitude': '-8...  41.8800834614
# 21  {'latitude': '41.9740944511', 'longitude': '-8...  41.9740944511
# 22  {'latitude': '41.9660534171', 'longitude': '-8...  41.9660534171
#
#               long
# 0   -87.6233953459
# 1   -87.6433521393
# 2    -87.651512018
# 3   -87.6928445094
# 4   -87.6685203937
# 5   -87.6713242922
# 6    -87.765574479
# 7    -87.627356171
# 8   -87.6305601801
# 9   -87.6057478606
# 10  -87.5683491228
# 11  -87.6045058667
# 12  -87.6442289066
# 13  -87.6608870173
# 14  -87.7088638153
# 15  -87.6464077068
# 16   -87.708381958
# 17   -87.705488126
# 18  -87.6569725149
# 19  -87.6974518223
# 20   -87.768199889
# 21  -87.7661488432
# 22   -87.728114561

# %%
#Attach geo ids
gdf_ps = gpd.GeoDataFrame(
    police_stations, geometry=gpd.points_from_xy(police_stations.long, police_stations.lat), crs = 'epsg:4326')

ps_acs = gpd.sjoin(gdf_ps, gdf_acs[['geo_id','geometry']], how='left' )

ps_acs
# Out:
#         district   district_name    zip  \
# 0   Headquarters    Headquarters  60653
# 1             18      Near North  60610
# 2             19       Town Hall  60613
# 3             20         Lincoln  60625
# 4             22     Morgan Park  60643
# 5             24     Rogers Park  60626
# 6             25   Grand Central  60639
# 7              1         Central  60616
# 8              2       Wentworth  60609
# 9              3  Grand Crossing  60637
# 10             4   South Chicago  60617
# 11             5         Calumet  60628
# 12             6         Gresham  60620
# 13             7       Englewood  60636
# 14             8    Chicago Lawn  60629
# 15             9         Deering  60608
# 16            10           Ogden  60623
# 17            11        Harrison  60612
# 18            12       Near West  60608
# 19            14     Shakespeare  60647
# 20            15          Austin  60644
# 21            16  Jefferson Park  60630
# 22            17     Albany Park  60630
#
#                                              location            lat  \
# 0   {'latitude': '41.8307016873', 'longitude': '-8...  41.8307016873
# 1   {'latitude': '41.9032416531', 'longitude': '-8...  41.9032416531
# 2   {'latitude': '41.9474004564', 'longitude': '-8...  41.9474004564
# 3   {'latitude': '41.9795495131', 'longitude': '-8...  41.9795495131
# 4   {'latitude': '41.6914347795', 'longitude': '-8...  41.6914347795
# 5   {'latitude': '41.9997634842', 'longitude': '-8...  41.9997634842
# 6   {'latitude': '41.9186088912', 'longitude': '-8...  41.9186088912
# 7   {'latitude': '41.8583725929', 'longitude': '-8...  41.8583725929
# 8   {'latitude': '41.8018110912', 'longitude': '-8...  41.8018110912
# 9   {'latitude': '41.7664308925', 'longitude': '-8...  41.7664308925
# 10  {'latitude': '41.7079332906', 'longitude': '-8...  41.7079332906
# 11  {'latitude': '41.6927233639', 'longitude': '-8...  41.6927233639
# 12  {'latitude': '41.7521368378', 'longitude': '-8...  41.7521368378
# 13  {'latitude': '41.7796315359', 'longitude': '-8...  41.7796315359
# 14  {'latitude': '41.778987189', 'longitude': '-87...   41.778987189
# 15  {'latitude': '41.8373944311', 'longitude': '-8...  41.8373944311
# 16  {'latitude': '41.8566845327', 'longitude': '-8...  41.8566845327
# 17  {'latitude': '41.8735822883', 'longitude': '-8...  41.8735822883
# 18  {'latitude': '41.8629766244', 'longitude': '-8...  41.8629766244
# 19  {'latitude': '41.9211033246', 'longitude': '-8...  41.9211033246
# 20  {'latitude': '41.8800834614', 'longitude': '-8...  41.8800834614
# 21  {'latitude': '41.9740944511', 'longitude': '-8...  41.9740944511
# 22  {'latitude': '41.9660534171', 'longitude': '-8...  41.9660534171
#
#               long                    geometry  index_right  \
# 0   -87.6233953459  POINT (-87.62340 41.83070)          399
# 1   -87.6433521393  POINT (-87.64335 41.90324)          781
# 2    -87.651512018  POINT (-87.65151 41.94740)           83
# 3   -87.6928445094  POINT (-87.69284 41.97955)           55
# 4   -87.6685203937  POINT (-87.66852 41.69143)          678
# 5   -87.6713242922  POINT (-87.67132 41.99976)          689
# 6    -87.765574479  POINT (-87.76557 41.91861)          230
# 7    -87.627356171  POINT (-87.62736 41.85837)          390
# 8   -87.6305601801  POINT (-87.63056 41.80181)          728
# 9   -87.6057478606  POINT (-87.60575 41.76643)          440
# 10  -87.5683491228  POINT (-87.56835 41.70793)          753
# 11  -87.6045058667  POINT (-87.60451 41.69272)          495
# 12  -87.6442289066  POINT (-87.64423 41.75214)          647
# 13  -87.6608870173  POINT (-87.66089 41.77963)          603
# 14  -87.7088638153  POINT (-87.70886 41.77899)          588
# 15  -87.6464077068  POINT (-87.64641 41.83739)          546
# 16   -87.708381958  POINT (-87.70838 41.85668)          775
# 17   -87.705488126  POINT (-87.70549 41.87358)          744
# 18  -87.6569725149  POINT (-87.65697 41.86298)          787
# 19  -87.6974518223  POINT (-87.69745 41.92110)          259
# 20   -87.768199889  POINT (-87.76820 41.88008)          329
# 21  -87.7661488432  POINT (-87.76615 41.97409)          156
# 22   -87.728114561  POINT (-87.72811 41.96605)          171
#
#                   geo_id
# 0   1400000US17031351400
# 1   1400000US17031842200
# 2   1400000US17031061000
# 3   1400000US17031040202
# 4   1400000US17031750500
# 5   1400000US17031830600
# 6   1400000US17031191200
# 7   1400000US17031330200
# 8   1400000US17031835600
# 9   1400000US17031421200
# 10  1400000US17031838800
# 11  1400000US17031500300
# 12  1400000US17031710800
# 13  1400000US17031670800
# 14  1400000US17031660400
# 15  1400000US17031600900
# 16  1400000US17031841600
# 17  1400000US17031837300
# 18  1400000US17031842900
# 19  1400000US17031221300
# 20  1400000US17031252101
# 21  1400000US17031110400
# 22  1400000US17031140500

# %%
#Aggregate information at a census tract level
ps_acs['count'] = 1
ps_acs = ps_acs.groupby(['geo_id'],as_index = False)['count'].sum()
ps_acs.rename(columns = {"count":"police_stations"}, inplace = True)
ps_acs
# Out:
#                   geo_id  police_stations
# 0   1400000US17031040202                1
# 1   1400000US17031061000                1
# 2   1400000US17031110400                1
# 3   1400000US17031140500                1
# 4   1400000US17031191200                1
# 5   1400000US17031221300                1
# 6   1400000US17031252101                1
# 7   1400000US17031330200                1
# 8   1400000US17031351400                1
# 9   1400000US17031421200                1
# 10  1400000US17031500300                1
# 11  1400000US17031600900                1
# 12  1400000US17031660400                1
# 13  1400000US17031670800                1
# 14  1400000US17031710800                1
# 15  1400000US17031750500                1
# 16  1400000US17031830600                1
# 17  1400000US17031835600                1
# 18  1400000US17031837300                1
# 19  1400000US17031838800                1
# 20  1400000US17031841600                1
# 21  1400000US17031842200                1
# 22  1400000US17031842900                1

# %% [markdown]
# # Fire station locations

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("28km-gtjn", limit=2000)

# Convert to pandas DataFrame
fire_stations_locations = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
fire_stations_locations['lat'] = ''
fire_stations_locations['long'] = ''


for i in range(0,len(fire_stations_locations)):
    fire_stations_locations['lat'].iloc[i] = fire_stations_locations['location'].iloc[i]['latitude']
    fire_stations_locations['long'].iloc[i] = fire_stations_locations['location'].iloc[i]['longitude']
    

    
fire_stations_locations = fire_stations_locations[['name','address','zip','location','lat','long']]
fire_stations_locations
# Out:
#    name                address    zip  \
# 0    E5    324 S DESPLAINES ST  60661
# 1   E11  5343 N CUMBERLAND AVE  60656
# 2   E81      10458 S HOXIE AVE  60617
# 3   E22     605 W ARMITAGE AVE  60614
# 4   E50       5000 S UNION AVE  60609
# ..  ...                    ...    ...
# 87  E19     3421 S CALUMET AVE  60616
# 88  E26        10 N LEAVITT ST  60612
# 89  E82          817 E 91ST ST  60619
# 90  E34         4034 W 47TH ST  60632
# 91  E79      6424 N LEHIGH AVE  60646
#
#                                              location                 lat  \
# 0   {'latitude': '41.877028304420755', 'longitude'...  41.877028304420755
# 1   {'latitude': '41.97685625348317', 'longitude':...   41.97685625348317
# 2   {'latitude': '41.705334319654064', 'longitude'...  41.705334319654064
# 3   {'latitude': '41.91792047709303', 'longitude':...   41.91792047709303
# 4   {'latitude': '41.80344788181221', 'longitude':...   41.80344788181221
# ..                                                ...                 ...
# 87  {'latitude': '41.83227804024279', 'longitude':...   41.83227804024279
# 88  {'latitude': '41.88151592134697', 'longitude':...   41.88151592134697
# 89  {'latitude': '41.72933327959225', 'longitude':...   41.72933327959225
# 90  {'latitude': '41.80790024096418', 'longitude':...   41.80790024096418
# 91  {'latitude': '41.997974799017584', 'longitude'...  41.997974799017584
#
#                   long
# 0   -87.64430865193455
# 1     -87.836495886321
# 2   -87.56088524816063
# 3   -87.64396690956342
# 4   -87.64299386409898
# ..                 ...
# 87  -87.61779663851078
# 88  -87.68185534665783
# 89  -87.60425730151255
# 90  -87.72485128276466
# 91  -87.76616159362811
#
# [92 rows x 6 columns]

# %%
#Attach geo ids
gdf_fs = gpd.GeoDataFrame(
    fire_stations_locations, geometry=gpd.points_from_xy(fire_stations_locations.long, fire_stations_locations.lat), 
    crs = 'epsg:4326')

fs_acs = gpd.sjoin(gdf_fs, gdf_acs[['geo_id','geometry']], how='left' )

fs_acs
# Out:
#    name                address    zip  \
# 0    E5    324 S DESPLAINES ST  60661
# 1   E11  5343 N CUMBERLAND AVE  60656
# 2   E81      10458 S HOXIE AVE  60617
# 3   E22     605 W ARMITAGE AVE  60614
# 4   E50       5000 S UNION AVE  60609
# ..  ...                    ...    ...
# 87  E19     3421 S CALUMET AVE  60616
# 88  E26        10 N LEAVITT ST  60612
# 89  E82          817 E 91ST ST  60619
# 90  E34         4034 W 47TH ST  60632
# 91  E79      6424 N LEHIGH AVE  60646
#
#                                              location                 lat  \
# 0   {'latitude': '41.877028304420755', 'longitude'...  41.877028304420755
# 1   {'latitude': '41.97685625348317', 'longitude':...   41.97685625348317
# 2   {'latitude': '41.705334319654064', 'longitude'...  41.705334319654064
# 3   {'latitude': '41.91792047709303', 'longitude':...   41.91792047709303
# 4   {'latitude': '41.80344788181221', 'longitude':...   41.80344788181221
# ..                                                ...                 ...
# 87  {'latitude': '41.83227804024279', 'longitude':...   41.83227804024279
# 88  {'latitude': '41.88151592134697', 'longitude':...   41.88151592134697
# 89  {'latitude': '41.72933327959225', 'longitude':...   41.72933327959225
# 90  {'latitude': '41.80790024096418', 'longitude':...   41.80790024096418
# 91  {'latitude': '41.997974799017584', 'longitude'...  41.997974799017584
#
#                   long                    geometry  index_right  \
# 0   -87.64430865193455  POINT (-87.64431 41.87703)          353
# 1     -87.836495886321  POINT (-87.83650 41.97686)          150
# 2   -87.56088524816063  POINT (-87.56089 41.70533)          753
# 3   -87.64396690956342  POINT (-87.64397 41.91792)          124
# 4   -87.64299386409898  POINT (-87.64299 41.80345)          796
# ..                 ...                         ...          ...
# 87  -87.61779663851078  POINT (-87.61780 41.83228)          757
# 88  -87.68185534665783  POINT (-87.68186 41.88152)          746
# 89  -87.60425730151255  POINT (-87.60426 41.72933)          462
# 90  -87.72485128276466  POINT (-87.72485 41.80790)          527
# 91  -87.76616159362811  POINT (-87.76616 41.99797)          159
#
#                   geo_id
# 0   1400000US17031281900
# 1   1400000US17031100500
# 2   1400000US17031838800
# 3   1400000US17031071800
# 4   1400000US17031843800
# ..                   ...
# 87  1400000US17031839500
# 88  1400000US17031837800
# 89  1400000US17031440800
# 90  1400000US17031570200
# 91  1400000US17031120100
#
# [92 rows x 9 columns]

# %%
#Aggregate information at a census tract level
fs_acs['count'] = 1
fs_acs = fs_acs.groupby(['geo_id'],as_index = False)['count'].sum()
fs_acs.rename(columns = {"count":"fire_stations"}, inplace = True)
fs_acs
# Out:
#                   geo_id  fire_stations
# 0   1400000US17031010202              1
# 1   1400000US17031020802              1
# 2   1400000US17031030300              1
# 3   1400000US17031031700              1
# 4   1400000US17031040100              1
# ..                   ...            ...
# 85  1400000US17031843300              1
# 86  1400000US17031843600              1
# 87  1400000US17031843700              1
# 88  1400000US17031843800              1
# 89  1400000US17031843900              1
#
# [90 rows x 2 columns]

# %% [markdown]
# # Public Schools (as of 2019)

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("tz49-n8ze", limit=2000)

# Convert to pandas DataFrame
schools = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
schools = schools.rename(columns = {'x':'long','y':'lat'})
schools = schools[['school_id','school_nm','sch_type','lat','long']]
schools
# Out:
#     school_id               school_nm     sch_type          lat          long
# 0      610587           DYETT ARTS HS  Traditional  41.80120417  -87.61223911
# 1      400111         LEARN - PERKINS  Traditional  41.74312177  -87.66572106
# 2      610568  PATHWAYS - AVONDALE HS      Options  41.93943321  -87.70520632
# 3      610027                 KIPLING  Traditional  41.72362691  -87.63952072
# 4      609712               HIRSCH HS  Traditional  41.75374796  -87.60172727
# ..        ...                     ...          ...          ...           ...
# 649    610200                 THORP J  Traditional  41.73332424  -87.54427998
# 650    610139                 PULLMAN  Traditional  41.68881935  -87.60943097
# 651    610026                  KINZIE  Traditional  41.78996463   -87.7794826
# 652    609844                  CARTER  Traditional  41.78982791  -87.62245275
# 653    400147      CAMELOT - EXCEL HS      Options  41.69196931  -87.65372654
#
# [654 rows x 5 columns]

# %%
#Attach geo ids
gdf_school = gpd.GeoDataFrame(
    schools, geometry=gpd.points_from_xy(schools.long, schools.lat), 
    crs = 'epsg:4326')

schools_acs = gpd.sjoin(gdf_school, gdf_acs[['geo_id','geometry']], how='left' )

schools_acs
# Out:
#     school_id               school_nm     sch_type          lat          long  \
# 0      610587           DYETT ARTS HS  Traditional  41.80120417  -87.61223911
# 1      400111         LEARN - PERKINS  Traditional  41.74312177  -87.66572106
# 2      610568  PATHWAYS - AVONDALE HS      Options  41.93943321  -87.70520632
# 3      610027                 KIPLING  Traditional  41.72362691  -87.63952072
# 4      609712               HIRSCH HS  Traditional  41.75374796  -87.60172727
# ..        ...                     ...          ...          ...           ...
# 649    610200                 THORP J  Traditional  41.73332424  -87.54427998
# 650    610139                 PULLMAN  Traditional  41.68881935  -87.60943097
# 651    610026                  KINZIE  Traditional  41.78996463   -87.7794826
# 652    609844                  CARTER  Traditional  41.78982791  -87.62245275
# 653    400147      CAMELOT - EXCEL HS      Options  41.69196931  -87.65372654
#
#                        geometry  index_right                geo_id
# 0    POINT (-87.61224 41.80120)        733.0  1400000US17031836100
# 1    POINT (-87.66572 41.74312)        651.0  1400000US17031711200
# 2    POINT (-87.70521 41.93943)        238.0  1400000US17031210100
# 3    POINT (-87.63952 41.72363)        662.0  1400000US17031730100
# 4    POINT (-87.60173 41.75375)        631.0  1400000US17031691500
# ..                          ...          ...                   ...
# 649  POINT (-87.54428 41.73332)        714.0  1400000US17031833900
# 650  POINT (-87.60943 41.68882)        495.0  1400000US17031500300
# 651  POINT (-87.77948 41.78996)        525.0  1400000US17031561100
# 652  POINT (-87.62245 41.78983)        420.0  1400000US17031400500
# 653  POINT (-87.65373 41.69197)        679.0  1400000US17031750600
#
# [654 rows x 8 columns]

# %%
#Aggregate information at a census tract level
schools_acs['count'] = 1
schools_acs = schools_acs.groupby(['geo_id'],as_index = False)['count'].sum()
schools_acs.rename(columns = {"count":"public_schools"}, inplace = True)
schools_acs
# Out:
#                    geo_id  public_schools
# 0    1400000US17031010100               1
# 1    1400000US17031010201               1
# 2    1400000US17031010202               1
# 3    1400000US17031010600               2
# 4    1400000US17031010702               1
# ..                    ...             ...
# 445  1400000US17031843200               1
# 446  1400000US17031843300               2
# 447  1400000US17031843500               1
# 448  1400000US17031843700               1
# 449  1400000US17031843800               2
#
# [450 rows x 2 columns]

# %% [markdown]
# # Parks (maintained by Chicago Park district)

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("y7qa-tvqx", limit=5000)

# Convert to pandas DataFrame
parks = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
parks['lat'] = ''
parks['long'] = ''


for i in range(0,len(parks)):
    parks['lat'].iloc[i] = parks['location'].iloc[i]['latitude']
    parks['long'].iloc[i] = parks['location'].iloc[i]['longitude']
    

    
parks = parks[['park','park_number','location','lat','long']]
parks = parks.drop_duplicates(subset = ['park_number'])

parks
# Out:
#                             park park_number  \
# 0                ABBOTT (ROBERT)         259
# 10          ADA (SAWYER GARRETT)          45
# 26        ADAMS (GEORGE & ADELE)        1019
# 28                 AIELLO (JOHN)        1280
# 29                     ALGONQUIN        1161
# ...                          ...         ...
# 3997             ROWAN (WILLIAM)         248
# 4022            RUTHERFORD SAYRE         127
# 4051           SCHAEFER (EDWARD)        1148
# 4060                      SENECA        1242
# 4108  SHEIL (BERNARD) COMM. CTR.         398
#
#                                                location        lat        long
# 0     {'latitude': '41.72096', 'longitude': '-87.621...   41.72096  -87.621351
# 10    {'latitude': '41.687785', 'longitude': '-87.65...  41.687785  -87.655389
# 26    {'latitude': '41.91689', 'longitude': '-87.655...   41.91689  -87.655092
# 28    {'latitude': '41.919151', 'longitude': '-87.77...  41.919151  -87.776356
# 29    {'latitude': '41.935202', 'longitude': '-87.69...  41.935202  -87.694918
# ...                                                 ...        ...         ...
# 3997  {'latitude': '41.686061', 'longitude': '-87.53...  41.686061  -87.538167
# 4022  {'latitude': '41.920557', 'longitude': '-87.79...  41.920557  -87.795929
# 4051  {'latitude': '41.925746', 'longitude': '-87.66...  41.925746  -87.669035
# 4060  {'latitude': '41.897006', 'longitude': '-87.62...  41.897006  -87.622414
# 4108  {'latitude': '41.945737', 'longitude': '-87.66...  41.945737  -87.663674
#
# [510 rows x 5 columns]

# %%
#Attach geo ids
gdf_parks = gpd.GeoDataFrame(
    parks, geometry=gpd.points_from_xy(parks.long, parks.lat), 
    crs = 'epsg:4326')

parks_acs = gpd.sjoin(gdf_parks, gdf_acs[['geo_id','geometry']], how='left' )

parks_acs
# Out:
#                             park park_number  \
# 0                ABBOTT (ROBERT)         259
# 10          ADA (SAWYER GARRETT)          45
# 26        ADAMS (GEORGE & ADELE)        1019
# 28                 AIELLO (JOHN)        1280
# 29                     ALGONQUIN        1161
# ...                          ...         ...
# 3997             ROWAN (WILLIAM)         248
# 4022            RUTHERFORD SAYRE         127
# 4051           SCHAEFER (EDWARD)        1148
# 4060                      SENECA        1242
# 4108  SHEIL (BERNARD) COMM. CTR.         398
#
#                                                location        lat  \
# 0     {'latitude': '41.72096', 'longitude': '-87.621...   41.72096
# 10    {'latitude': '41.687785', 'longitude': '-87.65...  41.687785
# 26    {'latitude': '41.91689', 'longitude': '-87.655...   41.91689
# 28    {'latitude': '41.919151', 'longitude': '-87.77...  41.919151
# 29    {'latitude': '41.935202', 'longitude': '-87.69...  41.935202
# ...                                                 ...        ...
# 3997  {'latitude': '41.686061', 'longitude': '-87.53...  41.686061
# 4022  {'latitude': '41.920557', 'longitude': '-87.79...  41.920557
# 4051  {'latitude': '41.925746', 'longitude': '-87.66...  41.925746
# 4060  {'latitude': '41.897006', 'longitude': '-87.62...  41.897006
# 4108  {'latitude': '41.945737', 'longitude': '-87.66...  41.945737
#
#             long                    geometry  index_right  \
# 0     -87.621351  POINT (-87.62135 41.72096)        482.0
# 10    -87.655389  POINT (-87.65539 41.68778)        679.0
# 26    -87.655092  POINT (-87.65509 41.91689)        709.0
# 28    -87.776356  POINT (-87.77636 41.91915)        231.0
# 29    -87.694918  POINT (-87.69492 41.93520)        246.0
# ...          ...                         ...          ...
# 3997  -87.538167  POINT (-87.53817 41.68606)        504.0
# 4022  -87.795929  POINT (-87.79593 41.92056)        699.0
# 4051  -87.669035  POINT (-87.66903 41.92575)        115.0
# 4060  -87.622414  POINT (-87.62241 41.89701)        134.0
# 4108  -87.663674  POINT (-87.66367 41.94574)         86.0
#
#                     geo_id
# 0     1400000US17031490500
# 10    1400000US17031750600
# 26    1400000US17031832600
# 28    1400000US17031191301
# 29    1400000US17031210900
# ...                    ...
# 3997  1400000US17031520600
# 4022  1400000US17031831600
# 4051  1400000US17031070700
# 4060  1400000US17031081300
# 4108  1400000US17031061500
#
# [510 rows x 8 columns]

# %%
#Aggregate information at a census tract level
parks_acs['count'] = 1
parks_acs = parks_acs.groupby(['geo_id'],as_index = False)['count'].sum()
parks_acs.rename(columns = {"count":"parks"}, inplace = True)
parks_acs
# Out:
#                    geo_id  parks
# 0    1400000US17031010100      3
# 1    1400000US17031010201      1
# 2    1400000US17031010202      2
# 3    1400000US17031010300      1
# 4    1400000US17031010400      3
# ..                    ...    ...
# 388  1400000US17031843100      1
# 389  1400000US17031843600      1
# 390  1400000US17031843700      2
# 391  1400000US17031843800      1
# 392  1400000US17031843900      1
#
# [393 rows x 2 columns]

# %% [markdown]
# # Commerical establishments

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("uupf-x98q", limit=60000)

# Convert to pandas DataFrame
comm_est = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
comm_est.dropna(subset = ['location'], inplace = True)

comm_est['lat'] = ''
comm_est['long'] = ''

#Loop takes some time to run
for i in range(0,len(comm_est)):
    comm_est['lat'].iloc[i] = comm_est['location'].iloc[i]['latitude']
    comm_est['long'].iloc[i] = comm_est['location'].iloc[i]['longitude']
    

    
comm_est = comm_est[['zip_code','license_description','license_id','police_district','location','lat','long']]
comm_est
# Out:
#       zip_code             license_description license_id police_district  \
# 0        60618        Limited Business License    2791110             NaN
# 1        60640    Manufacturing Establishments    2787279              19
# 2        60640  Motor Vehicle Services License    2788133              20
# 3        60657      Regulated Business License    2797190             NaN
# 4        60611        Limited Business License    2769315              18
# ...        ...                             ...        ...             ...
# 54882    60611          Valet Parking Operator    2785820              18
# 54883    60601          Valet Parking Operator    2791661               1
# 54884    60608               Commercial Garage    2797818              12
# 54885    60603          Valet Parking Operator    2802760               1
# 54886    60605          Valet Parking Operator    2808011               1
#
#                                                 location                 lat  \
# 0      {'latitude': '41.93702315598332', 'human_addre...   41.93702315598332
# 1      {'latitude': '41.964276736933826', 'human_addr...  41.964276736933826
# 2      {'latitude': '41.97237520416441', 'human_addre...   41.97237520416441
# 3      {'latitude': '41.939678060057524', 'human_addr...  41.939678060057524
# 4      {'latitude': '41.89497951109999', 'human_addre...   41.89497951109999
# ...                                                  ...                 ...
# 54882  {'latitude': '41.89475436857259', 'human_addre...   41.89475436857259
# 54883  {'latitude': '41.88637481521078', 'human_addre...   41.88637481521078
# 54884  {'latitude': '41.85598353104698', 'human_addre...   41.85598353104698
# 54885  {'latitude': '41.88066457839605', 'human_addre...   41.88066457839605
# 54886  {'latitude': '41.87171754808042', 'human_addre...   41.87171754808042
#
#                      long
# 0      -87.69508863011075
# 1      -87.67474581759035
# 2      -87.66804145559702
# 3      -87.67329284574338
# 4      -87.62439997045513
# ...                   ...
# 54882   -87.6243943466027
# 54883   -87.6246754356595
# 54884  -87.67314851164002
# 54885   -87.6270893644417
# 54886  -87.62431277689711
#
# [49745 rows x 7 columns]

# %%
#Attach geo ids
gdf_comm_est = gpd.GeoDataFrame(
    comm_est, geometry=gpd.points_from_xy(comm_est.long, comm_est.lat), 
    crs = 'epsg:4326')

comm_est_acs = gpd.sjoin(gdf_comm_est, gdf_acs[['geo_id','geometry']], how='left' )

comm_est_acs
# Out:
#       zip_code             license_description license_id police_district  \
# 0        60618        Limited Business License    2791110             NaN
# 1        60640    Manufacturing Establishments    2787279              19
# 2        60640  Motor Vehicle Services License    2788133              20
# 3        60657      Regulated Business License    2797190             NaN
# 4        60611        Limited Business License    2769315              18
# ...        ...                             ...        ...             ...
# 54882    60611          Valet Parking Operator    2785820              18
# 54883    60601          Valet Parking Operator    2791661               1
# 54884    60608               Commercial Garage    2797818              12
# 54885    60603          Valet Parking Operator    2802760               1
# 54886    60605          Valet Parking Operator    2808011               1
#
#                                                 location                 lat  \
# 0      {'latitude': '41.93702315598332', 'human_addre...   41.93702315598332
# 1      {'latitude': '41.964276736933826', 'human_addr...  41.964276736933826
# 2      {'latitude': '41.97237520416441', 'human_addre...   41.97237520416441
# 3      {'latitude': '41.939678060057524', 'human_addr...  41.939678060057524
# 4      {'latitude': '41.89497951109999', 'human_addre...   41.89497951109999
# ...                                                  ...                 ...
# 54882  {'latitude': '41.89475436857259', 'human_addre...   41.89475436857259
# 54883  {'latitude': '41.88637481521078', 'human_addre...   41.88637481521078
# 54884  {'latitude': '41.85598353104698', 'human_addre...   41.85598353104698
# 54885  {'latitude': '41.88066457839605', 'human_addre...   41.88066457839605
# 54886  {'latitude': '41.87171754808042', 'human_addre...   41.87171754808042
#
#                      long                    geometry  index_right  \
# 0      -87.69508863011075  POINT (-87.69509 41.93702)        246.0
# 1      -87.67474581759035  POINT (-87.67475 41.96428)        691.0
# 2      -87.66804145559702  POINT (-87.66804 41.97238)         42.0
# 3      -87.67329284574338  POINT (-87.67329 41.93968)         95.0
# 4      -87.62439997045513  POINT (-87.62440 41.89498)        138.0
# ...                   ...                         ...          ...
# 54882   -87.6243943466027  POINT (-87.62439 41.89475)        138.0
# 54883   -87.6246754356595  POINT (-87.62468 41.88637)        386.0
# 54884  -87.67314851164002  POINT (-87.67315 41.85598)        385.0
# 54885   -87.6270893644417  POINT (-87.62709 41.88066)        387.0
# 54886  -87.62431277689711  POINT (-87.62431 41.87172)        388.0
#
#                      geo_id
# 0      1400000US17031210900
# 1      1400000US17031830800
# 2      1400000US17031031000
# 3      1400000US17031062500
# 4      1400000US17031081500
# ...                     ...
# 54882  1400000US17031081500
# 54883  1400000US17031320100
# 54884  1400000US17031310900
# 54885  1400000US17031320400
# 54886  1400000US17031320600
#
# [49745 rows x 10 columns]

# %%
#Aggregate information at a census tract level
comm_est_acs['count'] = 1
comm_est_acs = comm_est_acs.groupby(['geo_id'],as_index = False)['count'].sum()
comm_est_acs.rename(columns = {"count":"commercial_establishments"}, inplace = True)
comm_est_acs
# Out:
#                    geo_id  commercial_establishments
# 0    1400000US17031010100                         24
# 1    1400000US17031010201                         30
# 2    1400000US17031010202                         58
# 3    1400000US17031010300                         71
# 4    1400000US17031010400                         41
# ..                    ...                        ...
# 788  1400000US17031843500                        121
# 789  1400000US17031843600                         42
# 790  1400000US17031843700                        117
# 791  1400000US17031843800                         31
# 792  1400000US17031843900                         30
#
# [793 rows x 2 columns]

# %% [markdown]
# # Police Killings

# %%
police_deaths = pd.read_csv(here("./data/raw/police_killings_MPV.csv"))

df_mask = police_deaths['City'] == "Chicago"
police_deaths = police_deaths[df_mask]

police_deaths = police_deaths[['Street Address of Incident','City','Zipcode','Agency responsible for death','Cause of death','MPV ID']]

police_deaths
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (21,22,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              Street Address of Incident     City  Zipcode  \
# 1            4900 South Lavergne Avenue  Chicago  60638.0
# 14          1300 block West 19th Street  Chicago  60608.0
# 663           3600 North Ashland Avenue  Chicago  60613.0
# 769               2660 East 79th Street  Chicago  60649.0
# 772             2100 North McVicker Ave  Chicago  60639.0
# ...                                 ...      ...      ...
# 7907      W 18th St & S Springfield Ave  Chicago  60623.0
# 8061  1300 South Independence Boulevard  Chicago  60623.0
# 8212            3300 West Wilson Avenue  Chicago  60625.0
# 8221             200 North Homan Avenue  Chicago  60624.0
# 8399  75th Street and Jeffery Boulevard  Chicago  60649.0
#
#      Agency responsible for death  Cause of death  MPV ID
# 1       Chicago Police Department         Gunshot    8446
# 14      Chicago Police Department         Gunshot    8438
# 663     Chicago Police Department         Gunshot    7780
# 769     Chicago Police Department  Gunshot, Taser    7676
# 772     Chicago Police Department         Gunshot    7670
# ...                           ...             ...     ...
# 7907    Chicago Police Department         Gunshot     518
# 8061    Chicago Police Department         Gunshot     370
# 8212    Chicago Police Department         Gunshot     217
# 8221    Chicago Police Department         Gunshot     208
# 8399    Chicago Police Department         Gunshot      28
#
# [84 rows x 6 columns]

# %%
#Getting geo-coordinates for the street addresses
google_apikey = 'AIzaSyDitOkTVs4g0ibg_Yt04DQqLaUYlxZ1o30'

#Defining the function that gets the lat long associated with a street address using google API

def getAddressCoords(input_address, api_key = google_apikey):
    params = {'key' : api_key,
              'address' : input_address}
    url = 'https://maps.googleapis.com/maps/api/geocode/json?'
    response = requests.get(url, params)
    result = json.loads(response.text)
    
    # Check these error codes again - there may be more
    if result['status'] not in ['INVALID_REQUEST', 'ZERO_RESULTS']:
                
        lat = result['results'][0]['geometry']['location']['lat']
        long = result['results'][0]['geometry']['location']['lng']
        place_id = result['results'][0]['place_id']

        return {"lat":lat, "long":long}
    
    # Flagging if there was an error
    else:
        return "Invalid address"
    
#Applying the function to police_deaths dataframe
police_deaths['place_coords'] = police_deaths[['Street Address of Incident']].apply(getAddressCoords, axis=1)

police_deaths
# Out:
#              Street Address of Incident     City  Zipcode  \
# 1            4900 South Lavergne Avenue  Chicago  60638.0
# 14          1300 block West 19th Street  Chicago  60608.0
# 663           3600 North Ashland Avenue  Chicago  60613.0
# 769               2660 East 79th Street  Chicago  60649.0
# 772             2100 North McVicker Ave  Chicago  60639.0
# ...                                 ...      ...      ...
# 7907      W 18th St & S Springfield Ave  Chicago  60623.0
# 8061  1300 South Independence Boulevard  Chicago  60623.0
# 8212            3300 West Wilson Avenue  Chicago  60625.0
# 8221             200 North Homan Avenue  Chicago  60624.0
# 8399  75th Street and Jeffery Boulevard  Chicago  60649.0
#
#      Agency responsible for death  Cause of death  MPV ID  \
# 1       Chicago Police Department         Gunshot    8446
# 14      Chicago Police Department         Gunshot    8438
# 663     Chicago Police Department         Gunshot    7780
# 769     Chicago Police Department  Gunshot, Taser    7676
# 772     Chicago Police Department         Gunshot    7670
# ...                           ...             ...     ...
# 7907    Chicago Police Department         Gunshot     518
# 8061    Chicago Police Department         Gunshot     370
# 8212    Chicago Police Department         Gunshot     217
# 8221    Chicago Police Department         Gunshot     208
# 8399    Chicago Police Department         Gunshot      28
#
#                                            place_coords
# 1                                       Invalid address
# 14      {'lat': 30.1829279, 'long': -85.68045610000001}
# 663            {'lat': 41.9473431, 'long': -87.6693382}
# 769            {'lat': 41.7521292, 'long': -87.5591115}
# 772     {'lat': 41.9180154, 'long': -87.77708539999999}
# ...                                                 ...
# 7907           {'lat': 41.8570763, 'long': -87.7223995}
# 8061           {'lat': 41.8642567, 'long': -87.7204673}
# 8212  {'lat': 41.96487219999999, 'long': -87.7110163...
# 8221    {'lat': 41.8847163, 'long': -87.71110279999999}
# 8399            {'lat': 41.7588674, 'long': -87.576149}
#
# [84 rows x 7 columns]

# %%
#Creating a lat long column

police_deaths = police_deaths[police_deaths['place_coords'] != 'Invalid address']

police_deaths['lat'] = police_deaths['place_coords'].apply(lambda x: x.get('lat'))
police_deaths['long'] = police_deaths['place_coords'].apply(lambda x: x.get('long'))

police_deaths
# Out:
# /var/folders/h_/mljy2_zs24d70d80xqt9v9_w0000gn/T/ipykernel_87404/1825511797.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_deaths['lat'] = police_deaths['place_coords'].apply(lambda x: x.get('lat'))
# /var/folders/h_/mljy2_zs24d70d80xqt9v9_w0000gn/T/ipykernel_87404/1825511797.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_deaths['long'] = police_deaths['place_coords'].apply(lambda x: x.get('long'))
#              Street Address of Incident     City  Zipcode  \
# 14          1300 block West 19th Street  Chicago  60608.0
# 663           3600 North Ashland Avenue  Chicago  60613.0
# 769               2660 East 79th Street  Chicago  60649.0
# 772             2100 North McVicker Ave  Chicago  60639.0
# 916               4318 W Irving Park Rd  Chicago  60641.0
# ...                                 ...      ...      ...
# 7907      W 18th St & S Springfield Ave  Chicago  60623.0
# 8061  1300 South Independence Boulevard  Chicago  60623.0
# 8212            3300 West Wilson Avenue  Chicago  60625.0
# 8221             200 North Homan Avenue  Chicago  60624.0
# 8399  75th Street and Jeffery Boulevard  Chicago  60649.0
#
#        Agency responsible for death  Cause of death  MPV ID  \
# 14        Chicago Police Department         Gunshot    8438
# 663       Chicago Police Department         Gunshot    7780
# 769       Chicago Police Department  Gunshot, Taser    7676
# 772       Chicago Police Department         Gunshot    7670
# 916   Des Plaines Police Department         Gunshot    7526
# ...                             ...             ...     ...
# 7907      Chicago Police Department         Gunshot     518
# 8061      Chicago Police Department         Gunshot     370
# 8212      Chicago Police Department         Gunshot     217
# 8221      Chicago Police Department         Gunshot     208
# 8399      Chicago Police Department         Gunshot      28
#
#                                            place_coords        lat       long
# 14      {'lat': 30.1829279, 'long': -85.68045610000001}  30.182928 -85.680456
# 663            {'lat': 41.9473431, 'long': -87.6693382}  41.947343 -87.669338
# 769            {'lat': 41.7521292, 'long': -87.5591115}  41.752129 -87.559112
# 772     {'lat': 41.9180154, 'long': -87.77708539999999}  41.918015 -87.777085
# 916            {'lat': 41.9537193, 'long': -87.7362994}  41.953719 -87.736299
# ...                                                 ...        ...        ...
# 7907           {'lat': 41.8570763, 'long': -87.7223995}  41.857076 -87.722399
# 8061           {'lat': 41.8642567, 'long': -87.7204673}  41.864257 -87.720467
# 8212  {'lat': 41.96487219999999, 'long': -87.7110163...  41.964872 -87.711016
# 8221    {'lat': 41.8847163, 'long': -87.71110279999999}  41.884716 -87.711103
# 8399            {'lat': 41.7588674, 'long': -87.576149}  41.758867 -87.576149
#
# [83 rows x 9 columns]

# %%
#Attach geo ids
gdf_police_deaths = gpd.GeoDataFrame(
    police_deaths, geometry=gpd.points_from_xy(police_deaths.long, police_deaths.lat), 
    crs = 'epsg:4326')

police_deaths_acs = gpd.sjoin(gdf_police_deaths, gdf_acs[['geo_id','geometry']], how='left' )

police_deaths_acs
# Out:
#              Street Address of Incident     City  Zipcode  \
# 14          1300 block West 19th Street  Chicago  60608.0
# 663           3600 North Ashland Avenue  Chicago  60613.0
# 769               2660 East 79th Street  Chicago  60649.0
# 772             2100 North McVicker Ave  Chicago  60639.0
# 916               4318 W Irving Park Rd  Chicago  60641.0
# ...                                 ...      ...      ...
# 7907      W 18th St & S Springfield Ave  Chicago  60623.0
# 8061  1300 South Independence Boulevard  Chicago  60623.0
# 8212            3300 West Wilson Avenue  Chicago  60625.0
# 8221             200 North Homan Avenue  Chicago  60624.0
# 8399  75th Street and Jeffery Boulevard  Chicago  60649.0
#
#        Agency responsible for death  Cause of death  MPV ID  \
# 14        Chicago Police Department         Gunshot    8438
# 663       Chicago Police Department         Gunshot    7780
# 769       Chicago Police Department  Gunshot, Taser    7676
# 772       Chicago Police Department         Gunshot    7670
# 916   Des Plaines Police Department         Gunshot    7526
# ...                             ...             ...     ...
# 7907      Chicago Police Department         Gunshot     518
# 8061      Chicago Police Department         Gunshot     370
# 8212      Chicago Police Department         Gunshot     217
# 8221      Chicago Police Department         Gunshot     208
# 8399      Chicago Police Department         Gunshot      28
#
#                                            place_coords        lat       long  \
# 14      {'lat': 30.1829279, 'long': -85.68045610000001}  30.182928 -85.680456
# 663            {'lat': 41.9473431, 'long': -87.6693382}  41.947343 -87.669338
# 769            {'lat': 41.7521292, 'long': -87.5591115}  41.752129 -87.559112
# 772     {'lat': 41.9180154, 'long': -87.77708539999999}  41.918015 -87.777085
# 916            {'lat': 41.9537193, 'long': -87.7362994}  41.953719 -87.736299
# ...                                                 ...        ...        ...
# 7907           {'lat': 41.8570763, 'long': -87.7223995}  41.857076 -87.722399
# 8061           {'lat': 41.8642567, 'long': -87.7204673}  41.864257 -87.720467
# 8212  {'lat': 41.96487219999999, 'long': -87.7110163...  41.964872 -87.711016
# 8221    {'lat': 41.8847163, 'long': -87.71110279999999}  41.884716 -87.711103
# 8399            {'lat': 41.7588674, 'long': -87.576149}  41.758867 -87.576149
#
#                         geometry  index_right                geo_id
# 14    POINT (-85.68046 30.18293)          NaN                   NaN
# 663   POINT (-87.66934 41.94734)         78.0  1400000US17031060300
# 769   POINT (-87.55911 41.75213)        452.0  1400000US17031431301
# 772   POINT (-87.77709 41.91802)        231.0  1400000US17031191301
# 916   POINT (-87.73630 41.95372)        191.0  1400000US17031160200
# ...                          ...          ...                   ...
# 7907  POINT (-87.72240 41.85708)        363.0  1400000US17031292400
# 8061  POINT (-87.72047 41.86426)        752.0  1400000US17031838700
# 8212  POINT (-87.71102 41.96487)        175.0  1400000US17031140702
# 8221  POINT (-87.71110 41.88472)        740.0  1400000US17031836800
# 8399  POINT (-87.57615 41.75887)        716.0  1400000US17031834200
#
# [83 rows x 12 columns]

# %%
#Aggregate information at a census tract level
police_deaths_acs['count'] = 1
police_deaths_acs = police_deaths_acs.groupby(['geo_id'],as_index = False)['count'].sum()
police_deaths_acs.rename(columns = {"count":"number_of_police_killings"}, inplace = True)
police_deaths_acs
# Out:
#                   geo_id  number_of_police_killings
# 0   1400000US17031020801                          1
# 1   1400000US17031060300                          1
# 2   1400000US17031071500                          1
# 3   1400000US17031110400                          1
# 4   1400000US17031140702                          1
# ..                   ...                        ...
# 63  1400000US17031838700                          2
# 64  1400000US17031839800                          1
# 65  1400000US17031843000                          2
# 66  1400000US17031843400                          1
# 67  1400000US17031843700                          1
#
# [68 rows x 2 columns]

# %% [markdown]
# # Reported crimes (2015-2019)

# %% [markdown]
# ### 2015

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("vwwp-7yr9", limit=270000)

# Convert to pandas DataFrame
crimes_2015 = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
crimes_2015 = crimes_2015.rename(columns = {"latitude":"lat","longitude":"long"})

crimes_2015 = crimes_2015[['lat','long','id']]

crimes_2015 = crimes_2015.dropna()
crimes_2015
# Out:
#                  lat           long        id
# 1       41.757366519  -87.642992854  10365064
# 2       41.751270452  -87.585822373  10364662
# 3       42.016804165  -87.690708662  10364740
# 4       41.949837364  -87.658635101  10364683
# 5       41.888165132  -87.622937212  10365142
# ...              ...            ...       ...
# 264603  41.921156927  -87.775623089  10327496
# 264604    41.9764212  -87.904976266  10083956
# 264605  41.949185407   -87.70177312  10328772
# 264606  41.751770335   -87.65255922  10024172
# 264608   41.79565153  -87.620868294   9963311
#
# [257911 rows x 3 columns]

# %%
#Attach geo ids
gdf_crimes_2015 = gpd.GeoDataFrame(
    crimes_2015, geometry=gpd.points_from_xy(crimes_2015.long, crimes_2015.lat), 
    crs = 'epsg:4326')

crimes_2015_acs = gpd.sjoin(gdf_crimes_2015, gdf_acs[['geo_id','geometry']], how='left' )

crimes_2015_acs
# Out:
#                  lat           long        id                    geometry  \
# 1       41.757366519  -87.642992854  10365064  POINT (-87.64299 41.75737)
# 2       41.751270452  -87.585822373  10364662  POINT (-87.58582 41.75127)
# 3       42.016804165  -87.690708662  10364740  POINT (-87.69071 42.01680)
# 4       41.949837364  -87.658635101  10364683  POINT (-87.65864 41.94984)
# 5       41.888165132  -87.622937212  10365142  POINT (-87.62294 41.88817)
# ...              ...            ...       ...                         ...
# 264603  41.921156927  -87.775623089  10327496  POINT (-87.77562 41.92116)
# 264604    41.9764212  -87.904976266  10083956  POINT (-87.90498 41.97642)
# 264605  41.949185407   -87.70177312  10328772  POINT (-87.70177 41.94919)
# 264606  41.751770335   -87.65255922  10024172  POINT (-87.65256 41.75177)
# 264608   41.79565153  -87.620868294   9963311  POINT (-87.62087 41.79565)
#
#         index_right                geo_id
# 1             620.0  1400000US17031681300
# 2             464.0  1400000US17031450300
# 3              12.0  1400000US17031020200
# 4              84.0  1400000US17031061100
# 5             386.0  1400000US17031320100
# ...             ...                   ...
# 264603        231.0  1400000US17031191301
# 264604          NaN                   NaN
# 264605        198.0  1400000US17031160700
# 264606        647.0  1400000US17031710800
# 264608        418.0  1400000US17031400300
#
# [257911 rows x 6 columns]

# %%
#Aggregate information at a census tract level
crimes_2015_acs['count'] = 1
crimes_2015_acs = crimes_2015_acs.groupby(['geo_id'],as_index = False)['count'].sum()
crimes_2015_acs.rename(columns = {"count":"total_crimes_2015"}, inplace = True)
crimes_2015_acs
# Out:
#                    geo_id  total_crimes_2015
# 0    1400000US17031010100                571
# 1    1400000US17031010201                376
# 2    1400000US17031010202                389
# 3    1400000US17031010300                345
# 4    1400000US17031010400                233
# ..                    ...                ...
# 793  1400000US17031843500                323
# 794  1400000US17031843600                314
# 795  1400000US17031843700                232
# 796  1400000US17031843800                370
# 797  1400000US17031843900                512
#
# [798 rows x 2 columns]

# %% [markdown]
# ### 2016

# %%
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("kf95-mnd6", limit=270000)

# Convert to pandas DataFrame
crimes_2016 = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
crimes_2016 = crimes_2016.rename(columns = {"latitude":"lat","longitude":"long"})

crimes_2016 = crimes_2016[['lat','long','id']]

crimes_2016 = crimes_2016.dropna()
crimes_2016
# Out:
#                  lat           long        id
# 0       41.976290414  -87.905227221  10819224
# 1       41.688033246  -87.623931468  10801137
# 2       41.936884881   -87.66476981  10801110
# 3       41.886814897  -87.625592678  10802006
# 4       41.752307019  -87.619797619  10801865
# ...              ...            ...       ...
# 269634  41.915573243  -87.759637797  11093786
# 269635  41.765282432  -87.583654702  11009258
# 269638  41.889525629  -87.755401321  10501254
# 269639  41.898549887  -87.700450413  10755601
# 269640  41.936176812  -87.721351222  10478256
#
# [267250 rows x 3 columns]

# %%
#Attach geo ids
gdf_crimes_2016 = gpd.GeoDataFrame(
    crimes_2016, geometry=gpd.points_from_xy(crimes_2016.long, crimes_2016.lat), 
    crs = 'epsg:4326')

crimes_2016_acs = gpd.sjoin(gdf_crimes_2016, gdf_acs[['geo_id','geometry']], how='left' )

crimes_2016_acs
# Out:
#                  lat           long        id                    geometry  \
# 0       41.976290414  -87.905227221  10819224  POINT (-87.90523 41.97629)
# 1       41.688033246  -87.623931468  10801137  POINT (-87.62393 41.68803)
# 2       41.936884881   -87.66476981  10801110  POINT (-87.66477 41.93688)
# 3       41.886814897  -87.625592678  10802006  POINT (-87.62559 41.88681)
# 4       41.752307019  -87.619797619  10801865  POINT (-87.61980 41.75231)
# ...              ...            ...       ...                         ...
# 269634  41.915573243  -87.759637797  11093786  POINT (-87.75964 41.91557)
# 269635  41.765282432  -87.583654702  11009258  POINT (-87.58365 41.76528)
# 269638  41.889525629  -87.755401321  10501254  POINT (-87.75540 41.88953)
# 269639  41.898549887  -87.700450413  10755601  POINT (-87.70045 41.89855)
# 269640  41.936176812  -87.721351222  10478256  POINT (-87.72135 41.93618)
#
#         index_right                geo_id
# 0               NaN                   NaN
# 1             491.0  1400000US17031491300
# 2              97.0  1400000US17031062700
# 3             386.0  1400000US17031320100
# 4             629.0  1400000US17031691300
# ...             ...                   ...
# 269634        312.0  1400000US17031250300
# 269635        446.0  1400000US17031430500
# 269638        323.0  1400000US17031251500
# 269639        302.0  1400000US17031242700
# 269640        241.0  1400000US17031210502
#
# [267250 rows x 6 columns]

# %%
#Aggregate information at a census tract level
crimes_2016_acs['count'] = 1
crimes_2016_acs = crimes_2016_acs.groupby(['geo_id'],as_index = False)['count'].sum()
crimes_2016_acs.rename(columns = {"count":"total_crimes_2016"}, inplace = True)
crimes_2016_acs
# Out:
#                    geo_id  total_crimes_2016
# 0    1400000US17031010100                498
# 1    1400000US17031010201                399
# 2    1400000US17031010202                385
# 3    1400000US17031010300                359
# 4    1400000US17031010400                322
# ..                    ...                ...
# 793  1400000US17031843500                326
# 794  1400000US17031843600                319
# 795  1400000US17031843700                267
# 796  1400000US17031843800                338
# 797  1400000US17031843900                478
#
# [798 rows x 2 columns]

# %% [markdown]
# ### 2017

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("d62x-nvdr", limit=270000)

# Convert to pandas DataFrame
crimes_2017 = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
crimes_2017 = crimes_2017.rename(columns = {"latitude":"lat","longitude":"long"})

crimes_2017 = crimes_2017[['lat','long','id']]

crimes_2017 = crimes_2017.dropna()
crimes_2017
# Out:
#                  lat           long        id
# 0       41.965693651  -87.715726125  11192233
# 1       41.926558908  -87.631294073  11196379
# 2       41.895750913  -87.623495923  11192540
# 3       41.856426716  -87.638892854  11192239
# 4       41.683369303  -87.622829524  11192254
# ...              ...            ...       ...
# 268866  41.763181833  -87.657790112  10902442
# 268870  41.889765267  -87.732580986  10874271
# 268871  41.882947966  -87.691879124  11092761
# 268873  41.947225755  -87.655523387  10801111
# 268874  41.774405884  -87.635727351  10801104
#
# [264941 rows x 3 columns]

# %%
#Attach geo ids
gdf_crimes_2017 = gpd.GeoDataFrame(
    crimes_2017, geometry=gpd.points_from_xy(crimes_2017.long, crimes_2017.lat), 
    crs = 'epsg:4326')

crimes_2017_acs = gpd.sjoin(gdf_crimes_2017, gdf_acs[['geo_id','geometry']], how='left' )

crimes_2017_acs
# Out:
#                  lat           long        id                    geometry  \
# 0       41.965693651  -87.715726125  11192233  POINT (-87.71573 41.96569)
# 1       41.926558908  -87.631294073  11196379  POINT (-87.63129 41.92656)
# 2       41.895750913  -87.623495923  11192540  POINT (-87.62350 41.89575)
# 3       41.856426716  -87.638892854  11192239  POINT (-87.63889 41.85643)
# 4       41.683369303  -87.622829524  11192254  POINT (-87.62283 41.68337)
# ...              ...            ...       ...                         ...
# 268866  41.763181833  -87.657790112  10902442  POINT (-87.65779 41.76318)
# 268870  41.889765267  -87.732580986  10874271  POINT (-87.73258 41.88977)
# 268871  41.882947966  -87.691879124  11092761  POINT (-87.69188 41.88295)
# 268873  41.947225755  -87.655523387  10801111  POINT (-87.65552 41.94723)
# 268874  41.774405884  -87.635727351  10801104  POINT (-87.63573 41.77441)
#
#         index_right                geo_id
# 0             175.0  1400000US17031140702
# 1             107.0  1400000US17031070101
# 2             135.0  1400000US17031081401
# 3             790.0  1400000US17031843200
# 4             506.0  1400000US17031530200
# ...             ...                   ...
# 268866        611.0  1400000US17031671800
# 268870        780.0  1400000US17031842100
# 268871        746.0  1400000US17031837800
# 268873         84.0  1400000US17031061100
# 268874        616.0  1400000US17031680900
#
# [264941 rows x 6 columns]

# %%
#Aggregate information at a census tract level
crimes_2017_acs['count'] = 1
crimes_2017_acs = crimes_2017_acs.groupby(['geo_id'],as_index = False)['count'].sum()
crimes_2017_acs.rename(columns = {"count":"total_crimes_2017"}, inplace = True)
crimes_2017_acs
# Out:
#                    geo_id  total_crimes_2017
# 0    1400000US17031010100                599
# 1    1400000US17031010201                510
# 2    1400000US17031010202                479
# 3    1400000US17031010300                418
# 4    1400000US17031010400                297
# ..                    ...                ...
# 793  1400000US17031843500                406
# 794  1400000US17031843600                393
# 795  1400000US17031843700                272
# 796  1400000US17031843800                370
# 797  1400000US17031843900                450
#
# [798 rows x 2 columns]

# %% [markdown]
# ### 2018

# %%
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("3i3m-jwuy", limit=270000)

# Convert to pandas DataFrame
crimes_2018 = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
crimes_2018 = crimes_2018.rename(columns = {"latitude":"lat","longitude":"long"})

crimes_2018 = crimes_2018[['lat','long','id']]

crimes_2018 = crimes_2018.dropna()
crimes_2018
# Out:
#                  lat           long        id
# 0       41.689078832  -87.696064026  11556487
# 1       41.763181359  -87.657709477  11561837
# 2       41.740520866  -87.647390719  11552699
# 3       41.857068095  -87.657625201  11552724
# 4        41.75191443  -87.647716532  11552731
# ...              ...            ...       ...
# 268479  41.895897782  -87.677740745  11267461
# 268481  41.780873262  -87.661824508  11315895
# 268483  41.922724629  -87.769594212  11262581
# 268486  41.756330614  -87.588307179  11369150
# 268489   41.76724809  -87.630214794  11257079
#
# [263458 rows x 3 columns]

# %%
#Attach geo ids
gdf_crimes_2018 = gpd.GeoDataFrame(
    crimes_2018, geometry=gpd.points_from_xy(crimes_2018.long, crimes_2018.lat), 
    crs = 'epsg:4326')

crimes_2018_acs = gpd.sjoin(gdf_crimes_2018, gdf_acs[['geo_id','geometry']], how='left' )

crimes_2018_acs
# Out:
#                  lat           long        id                    geometry  \
# 0       41.689078832  -87.696064026  11556487  POINT (-87.69606 41.68908)
# 1       41.763181359  -87.657709477  11561837  POINT (-87.65771 41.76318)
# 2       41.740520866  -87.647390719  11552699  POINT (-87.64739 41.74052)
# 3       41.857068095  -87.657625201  11552724  POINT (-87.65763 41.85707)
# 4        41.75191443  -87.647716532  11552731  POINT (-87.64772 41.75191)
# ...              ...            ...       ...                         ...
# 268479  41.895897782  -87.677740745  11267461  POINT (-87.67774 41.89590)
# 268481  41.780873262  -87.661824508  11315895  POINT (-87.66182 41.78087)
# 268483  41.922724629  -87.769594212  11262581  POINT (-87.76959 41.92272)
# 268486  41.756330614  -87.588307179  11369150  POINT (-87.58831 41.75633)
# 268489   41.76724809  -87.630214794  11257079  POINT (-87.63021 41.76725)
#
#         index_right                geo_id
# 0             670.0  1400000US17031740100
# 1             611.0  1400000US17031671800
# 2             649.0  1400000US17031711000
# 3             382.0  1400000US17031310600
# 4             647.0  1400000US17031710800
# ...             ...                   ...
# 268479        305.0  1400000US17031243000
# 268481        603.0  1400000US17031670800
# 268483        232.0  1400000US17031191302
# 268486        716.0  1400000US17031834200
# 268489        622.0  1400000US17031690300
#
# [263458 rows x 6 columns]

# %%
#Aggregate information at a census tract level
crimes_2018_acs['count'] = 1
crimes_2018_acs = crimes_2018_acs.groupby(['geo_id'],as_index = False)['count'].sum()
crimes_2018_acs.rename(columns = {"count":"total_crimes_2018"}, inplace = True)
crimes_2018_acs
# Out:
#                    geo_id  total_crimes_2018
# 0    1400000US17031010100                607
# 1    1400000US17031010201                420
# 2    1400000US17031010202                486
# 3    1400000US17031010300                340
# 4    1400000US17031010400                280
# ..                    ...                ...
# 793  1400000US17031843500                282
# 794  1400000US17031843600                399
# 795  1400000US17031843700                203
# 796  1400000US17031843800                315
# 797  1400000US17031843900                543
#
# [798 rows x 2 columns]

# %% [markdown]
# ### 2019

# %%
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("w98m-zvie", limit=270000)

# Convert to pandas DataFrame
crimes_2019 = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
crimes_2019 = crimes_2019.rename(columns = {"latitude":"lat","longitude":"long"})

crimes_2019 = crimes_2019[['lat','long','id']]

crimes_2019 = crimes_2019.dropna()
crimes_2019
# Out:
#                  lat           long        id
# 0       41.769150218  -87.627136786  11938228
# 1       41.779173667  -87.653277703  11940078
# 3       41.874623951  -87.745052647  11938240
# 4       41.877268465  -87.711536692  11937967
# 5       41.714095115  -87.652806763  11938124
# ...              ...            ...       ...
# 260853  41.907072136  -87.731331357  11992909
# 260855  41.896591951  -87.692793096  11947046
# 260856   41.65634477  -87.605129962  11739161
# 260857  41.876889551  -87.690074383  11589244
# 260858  41.968462892  -87.659670442  11553495
#
# [259135 rows x 3 columns]

# %%
#Attach geo ids
gdf_crimes_2019 = gpd.GeoDataFrame(
    crimes_2019, geometry=gpd.points_from_xy(crimes_2019.long, crimes_2019.lat), 
    crs = 'epsg:4326')

crimes_2019_acs = gpd.sjoin(gdf_crimes_2019, gdf_acs[['geo_id','geometry']], how='left' )

crimes_2019_acs
# Out:
#                  lat           long        id                    geometry  \
# 0       41.769150218  -87.627136786  11938228  POINT (-87.62714 41.76915)
# 1       41.779173667  -87.653277703  11940078  POINT (-87.65328 41.77917)
# 3       41.874623951  -87.745052647  11938240  POINT (-87.74505 41.87462)
# 4       41.877268465  -87.711536692  11937967  POINT (-87.71154 41.87727)
# 5       41.714095115  -87.652806763  11938124  POINT (-87.65281 41.71410)
# ...              ...            ...       ...                         ...
# 260853  41.907072136  -87.731331357  11992909  POINT (-87.73133 41.90707)
# 260855  41.896591951  -87.692793096  11947046  POINT (-87.69279 41.89659)
# 260856   41.65634477  -87.605129962  11739161  POINT (-87.60513 41.65634)
# 260857  41.876889551  -87.690074383  11589244  POINT (-87.69007 41.87689)
# 260858  41.968462892  -87.659670442  11553495  POINT (-87.65967 41.96846)
#
#         index_right                geo_id
# 0             622.0  1400000US17031690300
# 1             617.0  1400000US17031681000
# 3             332.0  1400000US17031252202
# 4             346.0  1400000US17031271400
# 5             666.0  1400000US17031730400
# ...             ...                   ...
# 260853        274.0  1400000US17031230600
# 260855        301.0  1400000US17031242600
# 260856        513.0  1400000US17031540101
# 260857        351.0  1400000US17031280800
# 260858         49.0  1400000US17031031700
#
# [259135 rows x 6 columns]

# %%
#Aggregate information at a census tract level
crimes_2019_acs['count'] = 1
crimes_2019_acs = crimes_2019_acs.groupby(['geo_id'],as_index = False)['count'].sum()
crimes_2019_acs.rename(columns = {"count":"total_crimes_2019"}, inplace = True)
crimes_2019_acs
# Out:
#                    geo_id  total_crimes_2019
# 0    1400000US17031010100                622
# 1    1400000US17031010201                401
# 2    1400000US17031010202                460
# 3    1400000US17031010300                434
# 4    1400000US17031010400                242
# ..                    ...                ...
# 793  1400000US17031843500                299
# 794  1400000US17031843600                400
# 795  1400000US17031843700                204
# 796  1400000US17031843800                258
# 797  1400000US17031843900                599
#
# [798 rows x 2 columns]

# %% [markdown]
# ### Creating one total crimes dataset

# %%
#Use the acs dataset with just geo_ids as the starting point
crimes_total = pd.DataFrame(acs['geo_id'])

#Merging the 5 year wise datasets
crimes_total = crimes_total.merge(crimes_2015_acs, how = 'left', on = 'geo_id')
crimes_total = crimes_total.merge(crimes_2016_acs, how = 'left', on = 'geo_id')
crimes_total = crimes_total.merge(crimes_2017_acs, how = 'left', on = 'geo_id')
crimes_total = crimes_total.merge(crimes_2018_acs, how = 'left', on = 'geo_id')
crimes_total = crimes_total.merge(crimes_2019_acs, how = 'left', on = 'geo_id')

#Creating a total crimes column
crimes_total['total_crimes_reported'] = crimes_total['total_crimes_2015'] + crimes_total['total_crimes_2016'] + crimes_total['total_crimes_2017'] + crimes_total['total_crimes_2018'] + crimes_total['total_crimes_2019']

crimes_total = crimes_total[['geo_id', 'total_crimes_reported']]
crimes_total
# Out:
#                    geo_id  total_crimes_2015  total_crimes_2016  \
# 0    1400000US17031010100                571                498
# 1    1400000US17031010201                376                399
# 2    1400000US17031010202                389                385
# 3    1400000US17031010300                345                359
# 4    1400000US17031010400                233                322
# ..                    ...                ...                ...
# 793  1400000US17031843500                323                326
# 794  1400000US17031843600                314                319
# 795  1400000US17031843700                232                267
# 796  1400000US17031843800                370                338
# 797  1400000US17031843900                512                478
#
#      total_crimes_2017  total_crimes_2018  total_crimes_2019  \
# 0                  599                607                622
# 1                  510                420                401
# 2                  479                486                460
# 3                  418                340                434
# 4                  297                280                242
# ..                 ...                ...                ...
# 793                406                282                299
# 794                393                399                400
# 795                272                203                204
# 796                370                315                258
# 797                450                543                599
#
#      total_crimes_reported
# 0                     2897
# 1                     2106
# 2                     2199
# 3                     1896
# 4                     1374
# ..                     ...
# 793                   1636
# 794                   1825
# 795                   1178
# 796                   1651
# 797                   2582
#
# [798 rows x 7 columns]

# %% [markdown]
# ## Merging all datasets

# %%
#Use the acs dataset with just geo_ids as the starting point
additional_predictors_final = pd.DataFrame(acs['geo_id'])

#Police stations
additional_predictors_final = additional_predictors_final.merge(ps_acs, how = 'left', on = 'geo_id')
additional_predictors_final['police_stations'] = additional_predictors_final['police_stations'].fillna(0)

#Fire stations
additional_predictors_final = additional_predictors_final.merge(fs_acs, how = 'left', on = 'geo_id')
additional_predictors_final['fire_stations'] = additional_predictors_final['fire_stations'].fillna(0)

#Schools
additional_predictors_final = additional_predictors_final.merge(schools_acs, how = 'left', on = 'geo_id')
additional_predictors_final['public_schools'] = additional_predictors_final['public_schools'].fillna(0)

#Parks
additional_predictors_final = additional_predictors_final.merge(parks_acs, how = 'left', on = 'geo_id')
additional_predictors_final['parks'] = additional_predictors_final['parks'].fillna(0)

#Commercial establishments
additional_predictors_final = additional_predictors_final.merge(comm_est_acs, how = 'left', on = 'geo_id')
additional_predictors_final['commercial_establishments'] = additional_predictors_final['commercial_establishments'].fillna(0)

#Police killings
additional_predictors_final = additional_predictors_final.merge(police_deaths_acs, how = 'left', on = 'geo_id')
additional_predictors_final['number_of_police_killings'] = additional_predictors_final['number_of_police_killings'].fillna(0)

#total_crimes
additional_predictors_final = additional_predictors_final.merge(crimes_total, how = 'left', on = 'geo_id')
additional_predictors_final['total_crimes_reported'] = additional_predictors_final['total_crimes_reported'].fillna(0)


#Display and export final dataset
additional_predictors_final.to_csv(here('./data/CleanOpenData.csv'), index = False)
additional_predictors_final
# Out:
#                    geo_id  police_stations  fire_stations  public_schools  \
# 0    1400000US17031010100              0.0            0.0             1.0
# 1    1400000US17031010201              0.0            0.0             1.0
# 2    1400000US17031010202              0.0            1.0             1.0
# 3    1400000US17031010300              0.0            0.0             0.0
# 4    1400000US17031010400              0.0            0.0             0.0
# ..                    ...              ...            ...             ...
# 793  1400000US17031843500              0.0            0.0             1.0
# 794  1400000US17031843600              0.0            1.0             0.0
# 795  1400000US17031843700              0.0            1.0             1.0
# 796  1400000US17031843800              0.0            1.0             2.0
# 797  1400000US17031843900              0.0            1.0             0.0
#
#      parks  commercial_establishments  number_of_police_killings  \
# 0      3.0                       24.0                        0.0
# 1      1.0                       30.0                        0.0
# 2      2.0                       58.0                        0.0
# 3      1.0                       71.0                        0.0
# 4      3.0                       41.0                        0.0
# ..     ...                        ...                        ...
# 793    0.0                      121.0                        0.0
# 794    1.0                       42.0                        0.0
# 795    2.0                      117.0                        1.0
# 796    1.0                       31.0                        0.0
# 797    1.0                       30.0                        0.0
#
#      total_crimes_reported
# 0                     2897
# 1                     2106
# 2                     2199
# 3                     1896
# 4                     1374
# ..                     ...
# 793                   1636
# 794                   1825
# 795                   1178
# 796                   1651
# 797                   2582
#
# [798 rows x 8 columns]
